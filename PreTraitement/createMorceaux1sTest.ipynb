# %%
import pandas as pd
from tqdm import tqdm

train_path_5s = "..\Dataset acoustique insectes\CSVs morceaux audio 5s\Audible\\train_audible_recording_chunks.csv"
df = pd.read_csv(train_path_5s)
new_df = pd.DataFrame(columns=df.columns)

for _, row in tqdm(df.iterrows()):
    chunk_initial_time = row["chunk_initial_time"]
    chunk_final_time = row["chunk_final_time"]
    annotation_initial_time = row["annotation_initial_time"]
    annotation_final_time = row["annotation_final_time"]

    time_start = chunk_initial_time
    while time_start < chunk_final_time:

        if annotation_initial_time < time_start + 1 and annotation_final_time > time_start:
            nouvelle_ligne = row
            nouvelle_ligne["chunk_initial_time"] = time_start
            nouvelle_ligne["chunk_final_time"] = time_start + 1
            new_df = pd.concat([new_df, pd.DataFrame([nouvelle_ligne])], ignore_index=True)

        time_start += 1
# Out:
# 0it [00:00, ?it/s]C:\Users\geogeo\AppData\Local\Temp\ipykernel_10404\2970675296.py:21: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   new_df = pd.concat([new_df, pd.DataFrame([nouvelle_ligne])], ignore_index=True)
# 1071it [00:27, 38.62it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 21
#      19     nouvelle_ligne["chunk_initial_time"] = time_start
#      20     nouvelle_ligne["chunk_final_time"] = time_start + 1
# ---> 21     new_df = pd.concat([new_df, pd.DataFrame([nouvelle_ligne])], ignore_index=True)
#      23 time_start += 1
#
# File d:\app\python\Lib\site-packages\pandas\core\reshape\concat.py:393, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     378     copy = False
#     380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#    (...)
#     390     sort=sort,
#     391 )
# --> 393 return op.get_result()
#
# File d:\app\python\Lib\site-packages\pandas\core\reshape\concat.py:682, in _Concatenator.get_result(self)
#     678             indexers[ax] = obj_labels.get_indexer(new_labels)
#     680     mgrs_indexers.append((obj._mgr, indexers))
# --> 682 new_data = concatenate_managers(
#     683     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     684 )
#     685 if not self.copy and not using_copy_on_write():
#     686     new_data._consolidate_inplace()
#
# File d:\app\python\Lib\site-packages\pandas\core\internals\concat.py:177, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     167 vals = [ju.block.values for ju in join_units]
#     169 if not blk.is_extension:
#     170     # _is_uniform_join_units ensures a single dtype, so
#     171     #  we can use np.concatenate, which is more performant
#    (...)
#     175     # expected "Union[_SupportsArray[dtype[Any]],
#     176     # _NestedSequence[_SupportsArray[dtype[Any]]]]"
# --> 177     values = np.concatenate(vals, axis=1)  # type: ignore[arg-type]
#     178 elif is_1d_only_ea_dtype(blk.dtype):
#     179     # TODO(EA2D): special-casing not needed with 2D EAs
#     180     values = concat_compat(vals, axis=0, ea_compat_axis=True)
#
# KeyboardInterrupt:

# %%
df.iloc[0].to_frame().T
# Out:
#   recording_chunk_id recording_id chunk_initial_time chunk_final_time  \
# 0                 86           16                  0                5
#
#   annotation_chunk_id annotation_initial_time annotation_final_time label  \
# 0                 266                0.355751              4.147038  Vent
#
#   sound_type label_category  ... BPS expansion_de_temps  \
# 0      Noise       Geophony  ...  16                non
#
#                                         localisation annotation  \
# 0  D:\PSI-BIOM\Travail\Enregistrements opportunis...        oui
#
#   annotation_exhaustive photo stereo notes avg_frequency frequency_category
# 0                   non   oui    non   NaN    187.613067            Audible
#
# [1 rows x 65 columns]

# %%
new_df
# Out:
#      recording_chunk_id recording_id chunk_initial_time chunk_final_time  \
# 0                    86           16                  0                1
# 1                    86           16                  1                2
# 2                    86           16                  2                3
# 3                    86           16                  3                4
# 4                    86           16                  4                5
# ...                 ...          ...                ...              ...
# 3904               2127          473                  6                7
# 3905               2127          473                  7                8
# 3906               2127          473                  8                9
# 3907               2127          473                  9               10
# 3908               2127          473                  5                6
#
#      annotation_chunk_id  annotation_initial_time  annotation_final_time  \
# 0                    266                 0.355751               4.147038
# 1                    266                 0.355751               4.147038
# 2                    266                 0.355751               4.147038
# 3                    266                 0.355751               4.147038
# 4                    266                 0.355751               4.147038
# ...                  ...                      ...                    ...
# 3904                4033                 5.000000               9.542278
# 3905                4033                 5.000000               9.542278
# 3906                4033                 5.000000               9.542278
# 3907                4033                 5.000000               9.542278
# 3908                4034                 5.000000              10.000000
#
#             label sound_type label_category  ... BPS expansion_de_temps  \
# 0            Vent      Noise       Geophony  ...  16                non
# 1            Vent      Noise       Geophony  ...  16                non
# 2            Vent      Noise       Geophony  ...  16                non
# 3            Vent      Noise       Geophony  ...  16                non
# 4            Vent      Noise       Geophony  ...  16                non
# ...           ...        ...            ...  ...  ..                ...
# 3904         Vent      Noise       Geophony  ...  16                non
# 3905         Vent      Noise       Geophony  ...  16                non
# 3906         Vent      Noise       Geophony  ...  16                non
# 3907         Vent      Noise       Geophony  ...  16                non
# 3908  Cicada orni     Animal      Hemiptera  ...  16                non
#
#                                            localisation annotation  \
# 0     D:\PSI-BIOM\Travail\Enregistrements opportunis...        oui
# 1     D:\PSI-BIOM\Travail\Enregistrements opportunis...        oui
# 2     D:\PSI-BIOM\Travail\Enregistrements opportunis...        oui
# 3     D:\PSI-BIOM\Travail\Enregistrements opportunis...        oui
# 4     D:\PSI-BIOM\Travail\Enregistrements opportunis...        oui
# ...                                                 ...        ...
# 3904  D:\PSI-BIOM\Travail\Enregistrements opportunis...        oui
# 3905  D:\PSI-BIOM\Travail\Enregistrements opportunis...        oui
# 3906  D:\PSI-BIOM\Travail\Enregistrements opportunis...        oui
# 3907  D:\PSI-BIOM\Travail\Enregistrements opportunis...        oui
# 3908  D:\PSI-BIOM\Travail\Enregistrements opportunis...        oui
#
#      annotation_exhaustive photo  stereo  notes avg_frequency  \
# 0                      non   oui     non    NaN    187.613067
# 1                      non   oui     non    NaN    187.613067
# 2                      non   oui     non    NaN    187.613067
# 3                      non   oui     non    NaN    187.613067
# 4                      non   oui     non    NaN    187.613067
# ...                    ...   ...     ...    ...           ...
# 3904                   non   oui     non    NaN    382.289795
# 3905                   non   oui     non    NaN    382.289795
# 3906                   non   oui     non    NaN    382.289795
# 3907                   non   oui     non    NaN    382.289795
# 3908                   non   oui     non    NaN   2734.617981
#
#      frequency_category
# 0               Audible
# 1               Audible
# 2               Audible
# 3               Audible
# 4               Audible
# ...                 ...
# 3904            Audible
# 3905            Audible
# 3906            Audible
# 3907            Audible
# 3908            Audible
#
# [3909 rows x 65 columns]
